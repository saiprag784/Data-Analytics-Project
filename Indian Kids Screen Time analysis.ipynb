# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA READING

# %%
scr_time=pd.read_csv(r"C:\Users\saipr\OneDrive\Documents\Dataset[1]\Dataset\Indian_Kids_Screen_Time.csv")

# %%
scr_time.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
scr_time.shape
# Out:
# (9712, 8)

# %%
scr_time.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
scr_time.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
scr_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
for i in scr_time.columns:
    print(i,':','\n',scr_time[i].unique())
# Out:
# Age :
#  [14 11 18 15 12 17 10 13  9  8 16]
# Gender :
#  ['Male' 'Female']
# Avg_Daily_Screen_Time_hr :
#  [3.990e+00 4.610e+00 3.730e+00 1.210e+00 5.890e+00 4.880e+00 2.970e+00
#  2.740e+00 3.240e+00 3.530e+00 4.940e+00 4.590e+00 6.080e+00 6.150e+00
#  3.690e+00 7.100e+00 6.980e+00 3.820e+00 0.000e+00 3.850e+00 4.050e+00
#  1.630e+00 6.780e+00 3.190e+00 4.960e+00 1.850e+00 4.220e+00 3.100e-01
#  5.130e+00 4.450e+00 3.020e+00 2.160e+00 4.280e+00 5.340e+00 3.500e+00
#  1.168e+01 4.630e+00 4.210e+00 4.560e+00 3.510e+00 4.690e+00 7.610e+00
#  2.750e+00 6.740e+00 2.340e+00 2.850e+00 4.290e+00 6.030e+00 1.060e+00
#  2.830e+00 3.920e+00 4.550e+00 6.860e+00 3.470e+00 4.310e+00 2.300e+00
#  4.500e+00 2.650e+00 3.870e+00 5.670e+00 3.800e+00 9.000e-01 3.300e+00
#  5.120e+00 5.820e+00 4.270e+00 5.790e+00 2.690e+00 3.640e+00 4.230e+00
#  5.720e+00 3.410e+00 2.900e+00 7.540e+00 4.340e+00 5.430e+00 4.780e+00
#  1.670e+00 5.910e+00 6.300e+00 3.390e+00 3.570e+00 1.360e+00 6.400e+00
# ...

# %%
scr_time.describe(include='all')
# Out:
#                 Age Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# count   9712.000000   9712               9712.000000           9712
# unique          NaN      2                       NaN              4
# top             NaN   Male                       NaN     Smartphone
# freq            NaN   4942                       NaN           4568
# mean      12.979201    NaN                  4.352837            NaN
# std        3.162437    NaN                  1.718232            NaN
# min        8.000000    NaN                  0.000000            NaN
# 25%       10.000000    NaN                  3.410000            NaN
# 50%       13.000000    NaN                  4.440000            NaN
# 75%       16.000000    NaN                  5.380000            NaN
# max       18.000000    NaN                 13.890000            NaN
#
#        Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# count                        9712                        9712.000000
# ...

# %% [markdown]
# # DATA ENCODING

# %%
scr_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   int64
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   int64
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   int64
#  8   team                               9712 non-null   int64
# dtypes: bool(1), float64(2), int64(5), object(1)
# memory usage: 616.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
scr_time.Gender = le.fit_transform(scr_time['Gender'])

# %%
le2 = LabelEncoder()
scr_time.Urban_or_Rural  = le2.fit_transform(scr_time['Urban_or_Rural'])

# %%
le3 = LabelEncoder()
scr_time.Primary_Device  = le2.fit_transform(scr_time['Primary_Device'])

# %%
le4 = LabelEncoder()
scr_time.Health_Impacts  = le2.fit_transform(scr_time['Health_Impacts'])

# %%
scr_time['Gender'].unique()
# Out:
# array([1, 0])

# %%
scr_time['Urban_or_Rural'].unique()
# Out:
# array([1, 0])

# %%
scr_time['Primary_Device'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
le.inverse_transform([1, 0])
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
le2.inverse_transform([1, 0])
# Out:
# array(['Anxiety, Obesity Risk', 'Anxiety'], dtype=object)

# %% [markdown]
# # DATA ANALYSIS

# %%
scr_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   int64
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   int64
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     9712 non-null   int64
#  7   Urban_or_Rural                     9712 non-null   int64
#  8   team                               9712 non-null   int64
# dtypes: bool(1), float64(2), int64(6)
# memory usage: 616.6 KB

# %%
sns.heatmap(c, annot=True, cmap="magma")
plt.show()

# %%
sns.pairplot(scr_time,hue='Avg_Daily_Screen_Time_hr')
plt.show()

# %% [markdown]
# # IP/OP CREATION

# %%
 ip = scr_time.drop('Avg_Daily_Screen_Time_hr',axis=1)
 op = scr_time.Avg_Daily_Screen_Time_hr

# %%
ip.head()
# Out:
#    Age  Gender  Primary_Device  Exceeded_Recommended_Limit  \
# 0   14       1               1                        True
# 1   11       0               0                        True
# 2   18       0               2                        True
# 3   15       0               0                       False
# 4   12       0               1                        True
#
#    Educational_to_Recreational_Ratio  Health_Impacts  Urban_or_Rural  team
# 0                               0.42              10               1     1
# 1                               0.30               7               1     0
# 2                               0.32               7               1     0
# 3                               0.39              15               1     0
# 4                               0.49               8               1     0

# %%
op.head()
# Out:
# 0    3.99
# 1    4.61
# 2    3.73
# 3    1.21
# 4    5.89
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# # MACHINE LEARING

# %% [markdown]
# #### LINEAR REGRESSION

# %%
 from sklearn.linear_model import LinearRegression
 lr = LinearRegression()
 lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(x_test)
ypred
# Out:
# array([1.56731107, 1.63751818, 4.79130203, ..., 4.78310553, 4.64881625,
#        4.84890452])

# %%
 from sklearn.metrics import r2_score,mean_squared_error
 r2 = r2_score(y_test,ypred)
 mse = mean_squared_error(y_test,ypred)
 print('R2_Score is :-',r2)
 print('Mean squared error is:',mse)
# Out:
# R2_Score is :- 0.4371644232865024
# Mean squared error is: 1.67653507084017

# %%
 df = pd.DataFrame({'Prediction':ypred,'Actual Data':y_test})
 sns.lmplot(df,x='Prediction',y='Actual Data')
 plt.show()
